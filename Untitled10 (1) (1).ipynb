# %%
import pandas as pd
from google.colab import files

def read_worldbank_data(file_path):
    # Read the World Bank data into a pandas dataframe
    worldbank_data = pd.read_csv(file_path, skiprows=4)

    # Extract relevant columns (Country Name, Country Code, and indicators for each year)
    columns_to_keep = ['Country Name', 'Country Code'] + [col for col in worldbank_data.columns if col.isnumeric()]
    worldbank_data = worldbank_data[columns_to_keep]

    # Transpose the dataframe to have years as columns
    worldbank_data_transposed = worldbank_data.set_index(['Country Name', 'Country Code']).T

    # Reset index for the transposed dataframe
    worldbank_data_transposed.reset_index(inplace=True)

    # Clean column names
    worldbank_data_transposed.columns.name = None

    return worldbank_data, worldbank_data_transposed

# Upload the 'climate.csv' file
uploaded = files.upload()

# Get the uploaded filename
filename = list(uploaded.keys())[0]

# Example usage
worldbank_data, worldbank_data_transposed = read_worldbank_data(filename)

# Print or use the dataframes as needed
print("Original Dataframe:")
print(worldbank_data.head())

print("\nTransposed Dataframe:")
print(worldbank_data_transposed.head())




# Example usage
worldbank_data, worldbank_data_transposed = read_worldbank_data(filename)

# Select a few indicators of interest
indicators_of_interest = ['Urban population', 'Access to electricity (% of population)', 'Agricultural irrigated land (% of total agricultural land), total (years)']

# Transpose the data again to have indicators as columns
worldbank_data_transposed = worldbank_data.set_index(['Country Name', 'Country Code']).T.reset_index()

# Explore statistical properties of indicators for selected countries
selected_countries = ['Australia', 'Canada', 'France', 'Japan', 'Pakistan']
selected_indicators = ['Urban population (% of total population)', 'Population, total', 'GDP (current US$)']

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-15b62c0a-ca20-42d8-aff2-f10eaf8ae8f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15b62c0a-ca20-42d8-aff2-f10eaf8ae8f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
# Replace 'your_dataset.csv' with the actual name of your dataset
df = pd.read_csv('studet 3.csv')
df.head()
df.describe()
# Out:
#               year      India     Israel   Pakistan  Russian Federation  \
# count    45.000000  45.000000  45.000000  45.000000           26.000000
# mean   1998.000000  63.441736  44.813478   0.335913           17.118897
# std      13.133926   7.841473  28.099626   0.322421            1.815575
# min    1976.000000  48.320606   0.000000   0.016961           14.317010
# 25%    1987.000000  56.819242  18.143831   0.100957           15.460406
# 50%    1998.000000  66.957876  54.412908   0.200347           17.244075
# 75%    2009.000000  68.499424  66.897871   0.620155           18.808619
# max    2020.000000  75.309399  77.175913   1.215003           19.877394
#
#        East Asia & Pacific (IDA & IBRD countries)  \
# count                                   45.000000
# mean                                    60.831305
# std                                      9.244559
# min                                     43.518452
# 25%                                     51.956128
# ...

# %%
correlation_matrix = df.corr()

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 18))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

import pandas as pd
import matplotlib.pyplot as plt

# Replace 'your_dataset.csv' with the actual filename or URL
df = pd.read_csv('studet 3.csv')

# Set the index of the DataFrame to the first column if it contains the years or time-related data
df.set_index(df.columns[0], inplace=True)

# Plotting trend graphs for selected columns
columns_of_interest = ['India', 'Israel', 'Pakistan', 'Russian Federation','East Asia & Pacific (IDA & IBRD countries)','Europe & Central Asia (IDA & IBRD countries)']

plt.figure(figsize=(10, 8))

for column in columns_of_interest:
    plt.plot(df.index, df[column], label=column)

plt.title('Trend Graphs for Selected Countries')
plt.xlabel('Year or Time')
plt.ylabel('Values')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
df_bar = df[columns_of_interest].mean()  # Using mean values for the bar chart
df_bar.plot(kind='bar', color='skyblue')
plt.title('Average Values for Selected Countries')
plt.xlabel('Country')
plt.ylabel('Average Values')
plt.show()

# Pie chart
plt.figure(figsize=(8, 8))
plt.pie(df_bar, labels=df_bar.index, autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightblue', 'lightgreen', 'lightpink'])
plt.title('Percentage Distribution of Average Values for Selected Countries/Indicators')
plt.show()

# Scatter plot
plt.figure(figsize=(10, 8))
for column in columns_of_interest:
    plt.scatter(df.index, df[column], label=column, alpha=0.7)

plt.title('Scatter Plot for Selected Countries')
plt.xlabel('Year or Time')
plt.ylabel('Values')
plt.legend()
plt.show()

# Box plot
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[columns_of_interest], palette='Set3')
plt.title('Box Plot for Selected Countries')
plt.ylabel('Values')
plt.show()
